# %%
using NBInclude
using PyPlot
nbinclude("LinearGraphLearning.ipynb")
nbinclude("AuxFunctions.ipynb")
# Out:
# evaluarLinearGraphLearning7 (generic function with 2 methods)

# %% [markdown]
# <h1>Pruebas<h1>

# %% [markdown]
# <h3>1) Con  una sola observacion<h3>

# %%
#Seed para las pruebas
srand(1236)

# %%
papa1 = Array{Any}(1)
papa1[1]=erdosgraph([0.8,1,1],0.1,[3,4],7)

# %% [markdown]
# <h3> 2) Aun con mas observarciones, el tamaño de la bola no influye el resultado: lambda brinca entre 0 y 1<h3>

# %%
papa2 = Array{Any}(5)
papa2[1]=erdosgraph([0.7,0.9],0.15,[3,4],7)
papa2[2]=erdosgraph([0.7,0.9],0.15,[3,4],7)
papa2[3]=erdosgraph([0.7,0.9],0.15,[3,4],7)
papa2[4]=erdosgraph([0.7,0.9],0.15,[3,4],7)
papa2[5]=erdosgraph([0.7,0.9],0.15,[3,4],7)
real = erdosgraph([1,1],0,[3,4],7)

# %%
resultado1=learnLinearGraph([1/5,1/5,1/5,1/5,1/5],1,papa2,7)
round.(resultado1[1]-real,2)

# %% [markdown]
# <h2>Ejemplo 1 de graph learning: Disminucion del error al aumentar el numero de observaciones y manteniendo el tamano de la
# bola fijo.<h2>

# %% [markdown]
# <h5>Cada corrida de evaluarLinearGraphLearning corre 4050 problemas de optimizacion<h5>

# %%
srand(1236) 
#TT = STDOUT # save original STDOUT stream
#redirect_stdout()
#solve(m)
#redirect_stdout(TT) # restore STDOUT

# %% [markdown]
# <h5>N=1<h5>

# %%
tic()
Eval1=evaluarLinearGraphLearning3(0.3,1)
toc()

# %%
imshow(Eval1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004886EEF0>)
# PyObject <matplotlib.image.AxesImage object at 0x00000000488CA320>

# %% [markdown]
# <h5>N=4<h5>

# %%
tic()
Eval4=evaluarLinearGraphLearning3(0.3,4)
toc()

# %%
imshow(Eval4)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000205B2B38>)
# PyObject <matplotlib.image.AxesImage object at 0x0000000020856EF0>

# %%
Eval4001=evaluarLinearGraphLearning3(0.001,4)

# %%
imshow(Eval4001)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000020B178D0>)
# PyObject <matplotlib.image.AxesImage object at 0x0000000020C62710>

# %%
Eval410=evaluarLinearGraphLearning3(10,4)

# %%
imshow(Eval410)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000020E08EF0>)
# PyObject <matplotlib.image.AxesImage object at 0x0000000020EAA320>

# %% [markdown]
# <h5>N=10<h5>

# %%
tic()
Eval10=evaluarLinearGraphLearning3(0.3,10)
toc()

# %%
imshow(Eval10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000208D8E48>)
# PyObject <matplotlib.image.AxesImage object at 0x00000000211A2EF0>

# %% [markdown]
# <h5>N=25<h5>

# %%
tic()
Eval25=evaluarLinearGraphLearning3(0.3,25)
toc()

# %%
imshow(Eval25)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000021290710>)
# PyObject <matplotlib.image.AxesImage object at 0x0000000021158B00>

# %%
Eval25001=evaluarLinearGraphLearning3(0.001,25)

# %%
imshow(Eval25001)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000021358E80>)
# PyObject <matplotlib.image.AxesImage object at 0x00000000484E6710>

# %% [markdown]
# <h2>Ejemplo 2 de graph learning: Disminución del error al mover el tamano de la bola y mantener constante la probabilidad intra cluster y outercluster<h2>

# %%
tic()
VarRad1 = evaluarLinearGraphLearning4(0.8,0.1,10,0.01:0.1:21)
toc()

# %%
plot(VarRad1[2],VarRad1[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000048C6EF28>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000048AB87F0>

# %%
tic()
VarRad2 = evaluarLinearGraphLearning4(0.8,0.1,10,0.01:0.01:1.2)
toc()

# %%
plot(VarRad2[2],VarRad2[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000213E8EB8>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000048F6E438>

# %% [markdown]
# <h5>Aumentemos la precision con 500 corridas...<h5>

# %%
tic()
VarRad4 = evaluarLinearGraphLearning4(0.8,0.1,10,0.4:0.001:0.6)
toc()

# %% [markdown]
# <h5>Esta simulacion de 500 * 200 = 100000 simulaciones tomo 5727/60 = 95 minutos <h5>

# %%
plot(VarRad4[2],VarRad4[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000491E4E48>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000493D7A20>

# %%
tic()
VarRad3 = evaluarLinearGraphLearning4(0.8,0.1,2,0.01:0.01:1.5)
toc()

# %%
plot(VarRad3[2],VarRad3[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000048BB44A8>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000491E4DA0>

# %% [markdown]
# <h5>Veamos que pasa en grafos mas dificiles de recuperar con inproba para el primer y tercer cluster y con 50 simulaciones para cada tamaño de bola.<h5>

# %%
tic()
VarRad5 = evaluarLinearGraphLearning4(0.7,0.3,10,0.01:0.1:5)
toc()

# %%
plot(VarRad5[2],VarRad5[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000493EFEF0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000477DD3C8>

# %%
tic()
estiLambda2 = evaluarLinearGraphLearning7(0.7,0.3,10,0.01:0.1:5)
toc()

# %%
plot(estiLambda[2],estiLambda[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000213F1F28>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000047A1C470>

# %%
tic()
estiLambda2 = evaluarLinearGraphLearning7(0.7,0.3,10,0.001:0.5:30)
toc()

# %%
plot(estiLambda2[2],estiLambda2[1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000047D4BB70>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000047D8FDD8>

# %% [markdown]
# <h2>Ejemplo 3 de graph learning: cambio del error al aumentar las observaciones<h2>

# %%
P = evaluarLinearGraphLearning6(0.7,0.3,0.01)
for s in [0.2,0.5,0.8,1.1,1.5,2,5,10]
    A = evaluarGraphLearning6(0.7,0.3,s)
    P = [P A]
    println(s)
end
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.2")
plot(1:1:30,P[1:30,3],label="delta=0.5")
plot(1:1:30,P[1:30,4],label="delta=0.8")
plot(1:1:30,P[1:30,5],label="delta=1.1")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")
plot(1:1:30,P[1:30,8],label="delta=5")
plot(1:1:30,P[1:30,9],label="delta=10")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
# Out:
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (2) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (3) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (5) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (7) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (8) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (9) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (11) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (12) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (13) of matrix 'A'.
# MOSEK warning 710: #1 (nearly) zero elements are specified in sparse col '' (14) of matrix 'A'.
# ...

# %%
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.2")
plot(1:1:30,P[1:30,3],label="delta=0.5")
plot(1:1:30,P[1:30,4],label="delta=0.8")
plot(1:1:30,P[1:30,5],label="delta=1.1")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")
plot(1:1:30,P[1:30,8],label="delta=5")
plot(1:1:30,P[1:30,9],label="delta=10")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000478A1048>)
# PyObject <matplotlib.legend.Legend object at 0x000000004DE3ABE0>
