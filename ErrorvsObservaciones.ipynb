# %%
#En este notebook ponemos las simulaciones que permiten observar la tasa de decaimiento de los errores
# a medida que se aumenta el numero de observaciones para los 4 metodos: lineal, l2, espectral y promedio.
#para diferentes valores del radio de la bola de Wasserstein.

# %%
#Todos los grafos aleatorios tienen 12 vertices, y tres clusters de tamaño 5,3,4.

# %%
using NBInclude
using PyPlot
@nbinclude("AuxFunctions.ipynb")
@nbinclude("GraphLearning.ipynb")
@nbinclude("admmRecovery.ipynb")

# %% [markdown]
# <h2>Aprendizaje con norma 1<h2>

# %%
tic()
P = evaluarLinearGraphLearning6(0.7,0.3,0.01)
for s in [0.2,0.8,1.5]
    A = evaluarLinearGraphLearning6(0.7,0.3,s)
    P = [P A]
    println(s)
end
toc()

# %%
#7.4 min
plot(1:1:30,P[1:30,1],label="delta=0.01","-bo")
plot(1:1:30,P[1:30,2],label="delta=0.5","-gs")
plot(1:1:30,P[1:30,3],label="delta=0.8","-m+")
plot(1:1:30,P[1:30,4],label="delta=1.5","-r^")


grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="Recovery using norm 1, 10 observations.","-bo")
p = zeros(length(interval))
plot(interval,resultadoL2[1],label="Recovery with norm 2, 7 observations.","-gs")
plot(interval,resultadoEspectral[1],label="Recovery using spectral norm, 7 observations.","-m+")
plot(interval,resultadoPromedioRedondeado,label="Recovery using the rounded mean, 7 observations.","-r^")
plot(interval,p,label="y=0")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
title("Error of recovery for different norms with 7 observations and varying \$\\delta\$")

# %% [markdown]
# <h2>Aprendizaje con norma 2<h2>

# %%
tic()
P = evaluarGraphLearningl26(0.7,0.3,0.01)
for s in [0.05,0.1,0.15,0.2,1.5,2]
    A = evaluarGraphLearningl26(0.7,0.3,s)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.05")
plot(1:1:30,P[1:30,3],label="delta=0.1")
plot(1:1:30,P[1:30,4],label="delta=0.15")
plot(1:1:30,P[1:30,5],label="delta=0.2")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")


grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h2>Aprendizaje con norma 2 y sin 1 en la diagonal<h2>

# %%
tic()
P = evaluarGraphLearningl262(0.7,0.3,0.01)
for s in [0.05,0.1,0.15,0.2,1.5,2]
    A = evaluarGraphLearningl262(0.7,0.3,s)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.05")
plot(1:1:30,P[1:30,3],label="delta=0.1")
plot(1:1:30,P[1:30,4],label="delta=0.15")
plot(1:1:30,P[1:30,5],label="delta=0.2")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")


grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h2>Aprendizaje con norma  espectral <h2>

# %%
tic()
P = evaluarGraphLearningEspectral6(0.75,0.2,0.01,false)
for s in [0.2,0.8,1.5]
    A = evaluarGraphLearningEspectral6(0.75,0.2,s,false)
    P = [P A]
    println(s)
end
toc()
# Out:
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 480
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 343
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 477               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   5.0e-01  1.6e+00  6.6e-01  3.95e-01   -4.521156522e+01  -4.550561040e+01  4.0e-01  0.05
# 2   2.9e-01  9.1e-01  4.4e-01  8.25e-01   -3.302524599e+01  -3.305609842e+01  2.3e-01  0.06
# 3   7.1e-02  2.3e-01  2.1e-01  8.91e-01   -5.615142070e+00  -5.603770252e+00  5.6e-02  0.06
# 4   3.0e-03  9.4e-03  3.8e-02  9.50e-01   3.212561663e-01   3.240795799e-01   2.4e-03  0.08
# 5   1.1e-03  3.5e-03  2.6e-02  1.17e+00   2.841344096e-01   2.846181967e-01   8.8e-04  0.09
# 6   2.2e-04  7.0e-04  1.2e-02  1.18e+00   2.680944208e-01   2.681491452e-01   1.8e-04  0.11
# 7   1.4e-05  4.4e-05  3.3e-03  1.06e+00   2.810624835e-01   2.810606748e-01   1.1e-05  0.13
# 8   1.2e-06  3.7e-06  9.6e-04  1.01e+00   2.817795035e-01   2.817793917e-01   9.3e-07  0.14
# 9   2.0e-07  6.4e-07  3.9e-04  1.00e+00   2.818680208e-01   2.818680317e-01   1.6e-07  0.16
# 10  6.8e-09  2.2e-08  5.4e-09  1.00e+00   2.818802209e-01   2.818802212e-01   5.4e-09  0.16
# Optimizer terminated. Time: 0.33
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.8188022089e-01    nrm: 6e+01    Viol.  con: 3e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.8188022120e-01    nrm: 2e+00    Viol.  con: 1e-08    var: 1e-08    barvar: 1e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 488
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 339
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 469               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   4.7e-01  1.5e+00  6.7e-01  4.27e-01   -4.206876851e+01  -4.242065423e+01  3.8e-01  0.05
# 2   2.6e-01  8.3e-01  4.4e-01  8.75e-01   -2.310111187e+01  -2.317885023e+01  2.1e-01  0.05
# 3   6.5e-02  2.1e-01  2.0e-01  8.58e-01   -3.747352050e+00  -3.731344306e+00  5.2e-02  0.06
# 4   2.4e-03  7.8e-03  3.4e-02  9.48e-01   3.177010105e-01   3.204635191e-01   2.0e-03  0.08
# 5   5.3e-04  1.7e-03  1.9e-02  1.20e+00   3.276421475e-01   3.276487515e-01   4.2e-04  0.09
# 6   4.5e-05  1.4e-04  6.3e-03  1.18e+00   3.323457380e-01   3.323220307e-01   3.6e-05  0.11
# 7   6.2e-06  2.0e-05  2.3e-03  1.02e+00   3.339629475e-01   3.339612222e-01   5.0e-06  0.11
# 8   2.7e-07  8.7e-07  4.8e-04  1.00e+00   3.342349828e-01   3.342348937e-01   2.2e-07  0.14
# 9   4.7e-09  1.5e-08  3.8e-09  1.00e+00   3.342488092e-01   3.342488087e-01   3.8e-09  0.14
# Optimizer terminated. Time: 0.16
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.3424880923e-01    nrm: 7e+01    Viol.  con: 2e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.3424880874e-01    nrm: 2e+00    Viol.  con: 8e-09    var: 8e-09    barvar: 8e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 480
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 343
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 477               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.01
# 1   4.9e-01  1.6e+00  6.6e-01  3.95e-01   -4.565796287e+01  -4.595537466e+01  3.9e-01  0.03
# 2   2.9e-01  9.1e-01  4.5e-01  8.39e-01   -3.139163590e+01  -3.144351902e+01  2.3e-01  0.05
# 3   7.9e-02  2.5e-01  2.2e-01  8.84e-01   -5.801194037e+00  -5.791367979e+00  6.3e-02  0.06
# 4   4.1e-03  1.3e-02  4.5e-02  9.41e-01   3.706054151e-01   3.744342124e-01   3.3e-03  0.08
# 5   4.5e-04  1.4e-03  2.0e-02  1.13e+00   3.079562706e-01   3.075134056e-01   3.6e-04  0.09
# 6   7.1e-05  2.3e-04  7.8e-03  1.23e+00   3.011272716e-01   3.010937152e-01   5.7e-05  0.11
# 7   5.8e-06  1.9e-05  2.4e-03  1.03e+00   3.078797559e-01   3.078755300e-01   4.7e-06  0.13
# 8   5.7e-07  1.8e-06  7.4e-04  1.00e+00   3.084919473e-01   3.084915430e-01   4.5e-07  0.13
# 9   2.4e-08  7.8e-08  1.5e-04  1.00e+00   3.085582521e-01   3.085582347e-01   2.0e-08  0.14
# 10  2.3e-10  7.5e-10  1.5e-05  1.00e+00   3.085608016e-01   3.085608015e-01   1.9e-10  0.16
# Optimizer terminated. Time: 0.16
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.0856080161e-01    nrm: 6e+01    Viol.  con: 1e-09    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.0856080146e-01    nrm: 2e+00    Viol.  con: 4e-10    var: 4e-10    barvar: 4e-10
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 490
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 338
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 467               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   4.9e-01  1.6e+00  6.8e-01  4.35e-01   -4.006867592e+01  -4.042737415e+01  3.9e-01  0.03
# 2   2.7e-01  8.5e-01  4.4e-01  8.66e-01   -2.302013274e+01  -2.309597539e+01  2.1e-01  0.05
# 3   8.5e-02  2.7e-01  2.3e-01  8.64e-01   -5.053988231e+00  -5.042840495e+00  6.8e-02  0.06
# 4   4.4e-03  1.4e-02  4.6e-02  9.35e-01   5.107781699e-01   5.156095614e-01   3.5e-03  0.08
# 5   5.1e-04  1.6e-03  2.1e-02  1.12e+00   3.483170398e-01   3.479410901e-01   4.1e-04  0.08
# 6   7.2e-05  2.3e-04  8.6e-03  1.24e+00   3.318514435e-01   3.317853274e-01   5.8e-05  0.09
# 7   6.2e-06  2.0e-05  2.7e-03  1.04e+00   3.325842113e-01   3.325774230e-01   5.0e-06  0.11
# 8   3.9e-07  1.2e-06  6.0e-04  1.00e+00   3.328316506e-01   3.328314247e-01   3.1e-07  0.13
# 9   1.1e-07  3.4e-07  3.0e-04  1.00e+00   3.328459590e-01   3.328459228e-01   8.5e-08  0.14
# 10  1.1e-08  3.5e-08  9.5e-05  1.00e+00   3.328519969e-01   3.328519941e-01   8.7e-09  0.16
# Optimizer terminated. Time: 0.16
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.3285199689e-01    nrm: 7e+01    Viol.  con: 5e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.3285199409e-01    nrm: 2e+00    Viol.  con: 2e-08    var: 2e-08    barvar: 2e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 480
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 343
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 477               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.01
# 1   4.6e-01  1.5e+00  6.4e-01  3.95e-01   -4.757248301e+01  -4.788339813e+01  3.7e-01  0.03
# 2   2.6e-01  8.5e-01  4.4e-01  8.71e-01   -2.806792329e+01  -2.813815536e+01  2.1e-01  0.05
# 3   6.8e-02  2.2e-01  2.0e-01  8.78e-01   -3.728005653e+00  -3.711148489e+00  5.5e-02  0.06
# 4   4.2e-03  1.3e-02  4.3e-02  9.42e-01   1.617488367e-02   2.216161233e-02   3.3e-03  0.08
# 5   4.4e-04  1.4e-03  1.8e-02  1.13e+00   3.101304891e-01   3.100203462e-01   3.5e-04  0.09
# 6   4.4e-05  1.4e-04  6.0e-03  1.17e+00   3.255851551e-01   3.255702938e-01   3.5e-05  0.11
# 7   8.5e-06  2.7e-05  2.6e-03  1.02e+00   3.315464770e-01   3.315443048e-01   6.8e-06  0.13
# 8   4.4e-07  1.4e-06  6.2e-04  1.00e+00   3.323122241e-01   3.323120469e-01   3.6e-07  0.14
# 9   1.9e-07  6.2e-07  4.0e-04  1.00e+00   3.323330059e-01   3.323329593e-01   1.5e-07  0.16
# 10  2.9e-08  9.1e-08  1.5e-04  1.00e+00   3.323509662e-01   3.323509662e-01   2.3e-08  0.17
# 11  4.5e-09  1.4e-08  5.7e-05  1.00e+00   3.323526910e-01   3.323526915e-01   3.6e-09  0.17
# Optimizer terminated. Time: 0.19
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.3235269095e-01    nrm: 6e+01    Viol.  con: 2e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.3235269151e-01    nrm: 2e+00    Viol.  con: 8e-09    var: 8e-09    barvar: 8e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 478
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 344
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 479               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   4.6e-01  1.5e+00  6.4e-01  3.88e-01   -4.892958186e+01  -4.923054124e+01  3.7e-01  0.03
# 2   2.6e-01  8.4e-01  4.3e-01  8.70e-01   -2.892043503e+01  -2.898507541e+01  2.1e-01  0.05
# 3   6.2e-02  2.0e-01  1.9e-01  8.72e-01   -2.997185759e+00  -2.977061537e+00  4.9e-02  0.06
# 4   2.0e-03  6.2e-03  3.1e-02  9.42e-01   2.525540802e-01   2.545111779e-01   1.6e-03  0.08
# 5   5.1e-04  1.6e-03  1.8e-02  1.23e+00   2.891833018e-01   2.892520285e-01   4.1e-04  0.09
# 6   6.7e-05  2.1e-04  7.0e-03  1.16e+00   3.164092841e-01   3.164160877e-01   5.4e-05  0.11
# 7   5.4e-06  1.7e-05  2.2e-03  1.02e+00   3.234549731e-01   3.234524895e-01   4.3e-06  0.11
# 8   5.9e-07  1.9e-06  6.8e-04  1.00e+00   3.238084707e-01   3.238083647e-01   4.7e-07  0.13
# 9   1.1e-07  3.5e-07  2.9e-04  1.00e+00   3.238530846e-01   3.238530766e-01   8.7e-08  0.14
# 10  1.4e-08  4.6e-08  1.0e-04  1.00e+00   3.238608951e-01   3.238608965e-01   1.1e-08  0.16
# Optimizer terminated. Time: 0.17
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.2386089514e-01    nrm: 6e+01    Viol.  con: 6e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.2386089648e-01    nrm: 2e+00    Viol.  con: 2e-08    var: 2e-08    barvar: 2e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 488
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1298
#   Cones                  : 0
#   Scalar variables       : 602
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 339
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 469               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.54e+04          after factor           : 4.56e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   4.9e-01  1.6e+00  6.7e-01  4.27e-01   -4.113974669e+01  -4.148281052e+01  3.9e-01  0.03
# 2   2.7e-01  8.6e-01  4.3e-01  8.43e-01   -2.755234770e+01  -2.759476023e+01  2.1e-01  0.05
# 3   9.8e-02  3.1e-01  2.5e-01  9.03e-01   -7.454169345e+00  -7.446842720e+00  7.9e-02  0.06
# 4   8.6e-03  2.8e-02  7.3e-02  9.35e-01   -1.668305072e-01  -1.671098584e-01  6.9e-03  0.08
# 5   4.0e-04  1.3e-03  2.2e-02  1.07e+00   2.830867038e-01   2.824807416e-01   3.2e-04  0.09
# 6   5.3e-05  1.7e-04  8.5e-03  1.19e+00   3.134106549e-01   3.133315027e-01   4.3e-05  0.11
# 7   7.2e-06  2.3e-05  2.8e-03  1.03e+00   3.173705234e-01   3.173629737e-01   5.8e-06  0.13
# 8   5.2e-07  1.7e-06  6.3e-04  1.00e+00   3.181003649e-01   3.181003633e-01   4.2e-07  0.14
# 9   3.1e-08  9.8e-08  1.5e-04  1.00e+00   3.181110212e-01   3.181110237e-01   2.4e-08  0.16
# 10  2.5e-09  8.0e-09  2.0e-09  1.00e+00   3.181123641e-01   3.181123644e-01   2.0e-09  0.17
# Optimizer terminated. Time: 0.17
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.1811236406e-01    nrm: 7e+01    Viol.  con: 1e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 3.1811236443e-01    nrm: 2e+00    Viol.  con: 4e-09    var: 4e-09    barvar: 4e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 690
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 382
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 555               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.56e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   5.3e-01  8.5e-01  7.1e-01  1.11e+00   -2.002143053e+01  -2.017904096e+01  4.3e-01  0.03
# 2   2.9e-01  4.7e-01  4.8e-01  1.04e+00   -7.032792127e+00  -6.993282053e+00  2.3e-01  0.05
# 3   7.5e-02  1.2e-01  2.4e-01  1.03e+00   1.049462247e+01   1.049811995e+01   6.0e-02  0.06
# 4   2.9e-03  4.6e-03  5.3e-02  9.83e-01   1.681976870e+01   1.681814603e+01   2.3e-03  0.08
# 5   8.8e-04  1.4e-03  3.2e-02  1.16e+00   1.711639831e+01   1.711583900e+01   7.1e-04  0.09
# 6   5.8e-05  9.3e-05  9.2e-03  1.10e+00   1.721976493e+01   1.721970945e+01   4.7e-05  0.11
# 7   1.6e-05  2.5e-05  4.7e-03  1.02e+00   1.722413662e+01   1.722412384e+01   1.3e-05  0.13
# 8   1.4e-06  2.3e-06  1.4e-03  1.01e+00   1.722566355e+01   1.722566253e+01   1.1e-06  0.14
# 9   2.0e-07  3.1e-07  4.8e-04  1.00e+00   1.722583725e+01   1.722583715e+01   1.6e-07  0.16
# 10  9.3e-08  1.5e-07  3.3e-04  1.00e+00   1.722584827e+01   1.722584823e+01   7.4e-08  0.17
# 11  8.6e-09  1.4e-08  1.0e-04  1.00e+00   1.722585652e+01   1.722585652e+01   6.9e-09  0.19
# Optimizer terminated. Time: 0.19
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.7225856522e+01    nrm: 7e+01    Viol.  con: 3e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 1.7225856518e+01    nrm: 2e+00    Viol.  con: 1e-08    var: 1e-08    barvar: 1e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 708
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 373
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 537               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.55e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   4.9e-01  7.9e-01  7.0e-01  1.14e+00   -1.677372532e+01  -1.694151318e+01  4.0e-01  0.05
# 2   2.8e-01  4.4e-01  4.7e-01  1.07e+00   -3.361737758e-01  -3.245565243e-01  2.2e-01  0.06
# 3   7.0e-02  1.1e-01  2.4e-01  1.03e+00   1.698078269e+01   1.698446618e+01   5.6e-02  0.08
# 4   1.0e-03  1.6e-03  5.9e-02  1.00e+00   2.601743673e+01   2.601505160e+01   8.1e-04  0.09
# 5   2.1e-04  3.3e-04  2.5e-02  1.28e+00   2.616699359e+01   2.616661714e+01   1.7e-04  0.11
# 6   4.3e-05  6.9e-05  9.4e-03  1.05e+00   2.620309814e+01   2.620303826e+01   3.5e-05  0.11
# 7   9.2e-06  1.5e-05  3.8e-03  1.01e+00   2.620807449e+01   2.620806518e+01   7.3e-06  0.14
# 8   1.2e-06  1.9e-06  1.4e-03  1.00e+00   2.620935762e+01   2.620935646e+01   9.3e-07  0.16
# 9   8.1e-08  1.3e-07  3.6e-04  1.00e+00   2.620954758e+01   2.620954749e+01   6.5e-08  0.17
# 10  9.0e-09  1.4e-08  1.2e-04  1.00e+00   2.620956203e+01   2.620956203e+01   7.2e-09  0.19
# Optimizer terminated. Time: 0.20
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.6209562035e+01    nrm: 9e+01    Viol.  con: 3e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.6209562025e+01    nrm: 2e+00    Viol.  con: 1e-08    var: 1e-08    barvar: 1e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 694
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 380
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 551               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.56e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   5.0e-01  8.0e-01  7.0e-01  1.12e+00   -1.981556234e+01  -1.998100401e+01  4.0e-01  0.05
# 2   2.8e-01  4.5e-01  4.7e-01  1.05e+00   -4.604955885e+00  -4.583369588e+00  2.2e-01  0.06
# 3   7.7e-02  1.2e-01  2.5e-01  1.04e+00   1.307501015e+01   1.308067260e+01   6.2e-02  0.08
# 4   2.4e-03  3.8e-03  4.9e-02  9.96e-01   2.078498298e+01   2.078352763e+01   1.9e-03  0.09
# 5   3.5e-04  5.6e-04  2.2e-02  1.18e+00   2.117529062e+01   2.117494397e+01   2.8e-04  0.11
# 6   6.6e-05  1.1e-04  9.6e-03  1.09e+00   2.121000945e+01   2.120995584e+01   5.3e-05  0.13
# 7   9.1e-06  1.5e-05  3.4e-03  1.02e+00   2.121435033e+01   2.121434439e+01   7.3e-06  0.14
# 8   1.4e-06  2.3e-06  1.4e-03  1.00e+00   2.121511953e+01   2.121511864e+01   1.2e-06  0.16
# 9   2.5e-07  4.0e-07  5.6e-04  1.00e+00   2.121523770e+01   2.121523755e+01   2.0e-07  0.17
# 10  3.5e-08  5.6e-08  2.1e-04  1.00e+00   2.121526423e+01   2.121526421e+01   2.8e-08  0.19
# 11  5.1e-09  8.1e-09  4.1e-09  1.00e+00   2.121526719e+01   2.121526718e+01   4.1e-09  0.20
# Optimizer terminated. Time: 0.20
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.1215267185e+01    nrm: 8e+01    Viol.  con: 2e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.1215267182e+01    nrm: 2e+00    Viol.  con: 7e-09    var: 7e-09    barvar: 7e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 688
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 383
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 557               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.56e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   4.8e-01  7.7e-01  6.9e-01  1.12e+00   -2.154625918e+01  -2.171438331e+01  3.9e-01  0.03
# 2   2.6e-01  4.1e-01  4.4e-01  1.03e+00   -7.488684613e+00  -7.438467590e+00  2.1e-01  0.05
# 3   6.3e-02  1.0e-01  2.2e-01  1.08e+00   1.378307736e+01   1.379006951e+01   5.0e-02  0.08
# 4   2.4e-03  3.8e-03  4.8e-02  9.99e-01   1.984835618e+01   1.984706340e+01   1.9e-03  0.09
# 5   4.4e-04  7.1e-04  2.4e-02  1.18e+00   2.016225206e+01   2.016191913e+01   3.5e-04  0.11
# 6   7.1e-05  1.1e-04  9.6e-03  1.09e+00   2.020778812e+01   2.020773999e+01   5.7e-05  0.13
# 7   1.3e-05  2.1e-05  4.1e-03  1.02e+00   2.021334617e+01   2.021333812e+01   1.1e-05  0.14
# 8   2.5e-06  4.0e-06  1.8e-03  1.00e+00   2.021446325e+01   2.021446176e+01   2.0e-06  0.16
# 9   3.9e-07  6.2e-07  7.0e-04  1.00e+00   2.021467888e+01   2.021467865e+01   3.1e-07  0.19
# 10  5.7e-08  9.1e-08  2.6e-04  1.00e+00   2.021472305e+01   2.021472302e+01   4.5e-08  0.19
# 11  7.7e-09  1.2e-08  6.1e-09  1.00e+00   2.021472912e+01   2.021472911e+01   6.1e-09  0.20
# Optimizer terminated. Time: 0.22
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.0214729115e+01    nrm: 6e+01    Viol.  con: 2e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.0214729111e+01    nrm: 2e+00    Viol.  con: 1e-08    var: 1e-08    barvar: 1e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 692
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 381
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 553               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.01              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.56e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.01
# 1   5.3e-01  8.4e-01  7.1e-01  1.11e+00   -1.987547769e+01  -2.003467881e+01  4.2e-01  0.03
# 2   2.9e-01  4.6e-01  4.6e-01  1.03e+00   -7.315964474e+00  -7.265679140e+00  2.3e-01  0.05
# 3   1.2e-01  2.0e-01  3.0e-01  1.03e+00   4.899895351e+00   4.924839988e+00   9.8e-02  0.06
# 4   1.4e-02  2.2e-02  1.0e-01  9.89e-01   1.308574043e+01   1.308593856e+01   1.1e-02  0.06
# 5   1.0e-03  1.7e-03  3.3e-02  1.05e+00   1.418045516e+01   1.417990455e+01   8.3e-04  0.08
# 6   1.5e-04  2.5e-04  1.4e-02  1.15e+00   1.423009852e+01   1.422998899e+01   1.2e-04  0.09
# 7   1.7e-05  2.7e-05  4.8e-03  1.04e+00   1.424022583e+01   1.424021273e+01   1.4e-05  0.11
# 8   2.3e-06  3.6e-06  1.7e-03  1.00e+00   1.424128787e+01   1.424128654e+01   1.8e-06  0.13
# 9   2.9e-07  4.6e-07  5.8e-04  1.00e+00   1.424142069e+01   1.424142053e+01   2.3e-07  0.13
# 10  4.8e-08  7.7e-08  2.4e-04  1.00e+00   1.424143607e+01   1.424143605e+01   3.9e-08  0.14
# 11  1.9e-08  3.0e-08  1.5e-04  1.00e+00   1.424143794e+01   1.424143793e+01   1.5e-08  0.16
# Optimizer terminated. Time: 0.16
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.4241437935e+01    nrm: 7e+01    Viol.  con: 6e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 1.4241437927e+01    nrm: 2e+00    Viol.  con: 3e-08    var: 3e-08    barvar: 3e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 698
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 378
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 547               conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.56e+04          after factor           : 4.57e+04
# Factor     - dense dim.             : 0                 flops                  : 9.48e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.01
# 1   5.1e-01  8.2e-01  7.1e-01  1.12e+00   -1.900858810e+01  -1.917163369e+01  4.1e-01  0.03
# 2   2.8e-01  4.4e-01  4.5e-01  1.03e+00   -7.253448883e+00  -7.191494560e+00  2.2e-01  0.05
# 3   7.3e-02  1.2e-01  2.3e-01  1.05e+00   9.280778103e+00   9.294021854e+00   5.8e-02  0.05
# 4   2.9e-03  4.6e-03  5.1e-02  9.90e-01   1.488671575e+01   1.488543439e+01   2.3e-03  0.06
# 5   5.3e-04  8.5e-04  2.6e-02  1.17e+00   1.519873015e+01   1.519824351e+01   4.3e-04  0.08
# 6   9.8e-05  1.6e-04  1.2e-02  1.14e+00   1.523411821e+01   1.523403634e+01   7.9e-05  0.09
# 7   1.1e-05  1.8e-05  3.8e-03  1.03e+00   1.523957663e+01   1.523956819e+01   8.8e-06  0.09
# 8   1.2e-06  1.9e-06  1.2e-03  1.00e+00   1.524044068e+01   1.524043992e+01   9.4e-07  0.11
# 9   1.9e-07  3.0e-07  4.7e-04  1.00e+00   1.524051230e+01   1.524051220e+01   1.5e-07  0.13
# 10  1.5e-08  2.4e-08  1.3e-04  1.00e+00   1.524052637e+01   1.524052636e+01   1.2e-08  0.14
# Optimizer terminated. Time: 0.14
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.5240526373e+01    nrm: 7e+01    Viol.  con: 5e-08    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 1.5240526364e+01    nrm: 2e+00    Viol.  con: 2e-08    var: 2e-08    barvar: 2e-08
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 688
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1587
#   Cones                  : 0
#   Scalar variables       : 681
# ...
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.03
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7078
#   Cones                  : 0
#   Scalar variables       : 2182
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1141
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2073              conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.44e+04          after factor           : 5.45e+04
# Factor     - dense dim.             : 0                 flops                  : 9.62e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   2.505218255e-13   2.505218255e-13   1.0e+00  0.05
# 1   7.4e-01  1.2e+00  1.2e+00  2.90e+00   4.303177037e+01   4.285385298e+01   5.9e-01  0.06
# 2   6.2e-01  1.0e+00  1.1e+00  1.93e+00   3.398699280e+01   3.388766350e+01   5.0e-01  0.08
# 3   1.7e-01  2.8e-01  9.4e-01  2.20e+00   2.625973128e+01   2.621094315e+01   1.4e-01  0.09
# 4   4.1e-02  6.5e-02  5.7e-01  1.29e+00   2.303101776e+01   2.301560850e+01   3.3e-02  0.11
# 5   1.7e-03  2.7e-03  1.5e-01  1.11e+00   2.205152639e+01   2.205074950e+01   1.4e-03  0.13
# 6   1.3e-04  2.1e-04  4.2e-02  1.04e+00   2.201070553e+01   2.201064603e+01   1.0e-04  0.14
# 7   3.2e-06  5.1e-06  6.8e-03  1.00e+00   2.200734763e+01   2.200734612e+01   2.5e-06  0.16
# 8   9.1e-09  1.5e-08  3.7e-04  1.00e+00   2.200725930e+01   2.200725930e+01   7.3e-09  0.19
# Optimizer terminated. Time: 0.19
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.2007259300e+01    nrm: 8e+01    Viol.  con: 6e-09    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.2007259296e+01    nrm: 2e+00    Viol.  con: 3e-09    var: 3e-09    barvar: 3e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7078
#   Cones                  : 0
#   Scalar variables       : 2182
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 4642
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7078
#   Cones                  : 0
#   Scalar variables       : 2182
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1142
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2075              conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.01              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.42e+04          after factor           : 5.44e+04
# Factor     - dense dim.             : 0                 flops                  : 9.62e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   2.429723089e-13   2.429723089e-13   1.0e+00  0.05
# 1   7.5e-01  1.2e+00  1.2e+00  2.90e+00   4.286531363e+01   4.268663124e+01   6.0e-01  0.06
# 2   6.3e-01  1.0e+00  1.1e+00  2.01e+00   3.563639452e+01   3.554291061e+01   5.0e-01  0.08
# 3   1.5e-01  2.4e-01  9.0e-01  2.18e+00   2.830116620e+01   2.825705605e+01   1.2e-01  0.09
# 4   5.0e-02  8.0e-02  5.9e-01  1.26e+00   2.530853087e+01   2.529114225e+01   4.0e-02  0.11
# 5   2.5e-03  3.9e-03  1.6e-01  1.12e+00   2.406982991e+01   2.406881645e+01   2.0e-03  0.13
# 6   1.7e-04  2.6e-04  4.3e-02  1.04e+00   2.401158350e+01   2.401151339e+01   1.3e-04  0.14
# 7   2.2e-06  3.6e-06  5.2e-03  1.00e+00   2.400731912e+01   2.400731815e+01   1.8e-06  0.16
# 8   3.6e-09  5.7e-09  2.1e-04  1.00e+00   2.400725914e+01   2.400725914e+01   2.9e-09  0.17
# Optimizer terminated. Time: 0.19
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.4007259143e+01    nrm: 8e+01    Viol.  con: 2e-09    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.4007259141e+01    nrm: 2e+00    Viol.  con: 1e-09    var: 1e-09    barvar: 1e-09
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 4866
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1174
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2139              conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.49e+04          after factor           : 5.50e+04
# Factor     - dense dim.             : 0                 flops                  : 9.63e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   9.336004192e-13   9.336004192e-13   1.0e+00  0.03
# 1   7.5e-01  1.2e+00  1.2e+00  2.91e+00   4.378894684e+01   4.360878306e+01   6.0e-01  0.06
# 2   6.3e-01  1.0e+00  1.1e+00  2.03e+00   3.624552287e+01   3.614730887e+01   5.0e-01  0.08
# 3   1.6e-01  2.5e-01  9.4e-01  2.20e+00   2.874685206e+01   2.869961566e+01   1.3e-01  0.08
# 4   5.5e-02  8.9e-02  6.4e-01  1.28e+00   2.571258493e+01   2.569381401e+01   4.4e-02  0.11
# 5   1.7e-03  2.7e-03  1.4e-01  1.13e+00   2.432902255e+01   2.432830556e+01   1.4e-03  0.13
# 6   1.1e-04  1.8e-04  3.7e-02  1.04e+00   2.429142982e+01   2.429138222e+01   9.0e-05  0.14
# 7   2.6e-06  4.2e-06  5.9e-03  1.00e+00   2.428871418e+01   2.428871303e+01   2.1e-06  0.16
# 8   2.3e-09  3.7e-09  1.8e-04  1.00e+00   2.428864439e+01   2.428864439e+01   1.8e-09  0.17
# Optimizer terminated. Time: 0.19
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.4288644389e+01    nrm: 8e+01    Viol.  con: 1e-09    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.4288644388e+01    nrm: 2e+00    Viol.  con: 7e-10    var: 7e-10    barvar: 7e-10
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 4848
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.03
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1183
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2157              conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.51e+04          after factor           : 5.52e+04
# Factor     - dense dim.             : 0                 flops                  : 9.64e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   8.865269630e-13   8.865269630e-13   1.0e+00  0.05
# 1   7.5e-01  1.2e+00  1.2e+00  2.92e+00   4.377881208e+01   4.360044764e+01   6.0e-01  0.06
# 2   6.3e-01  1.0e+00  1.1e+00  2.00e+00   3.548969464e+01   3.539196161e+01   5.0e-01  0.08
# 3   1.7e-01  2.8e-01  9.4e-01  2.22e+00   2.820133824e+01   2.815639902e+01   1.4e-01  0.09
# 4   5.1e-02  8.1e-02  6.1e-01  1.31e+00   2.489191523e+01   2.487494276e+01   4.1e-02  0.11
# 5   2.5e-03  4.0e-03  1.6e-01  1.12e+00   2.371152048e+01   2.371054140e+01   2.0e-03  0.13
# 6   1.5e-04  2.4e-04  4.2e-02  1.04e+00   2.365611453e+01   2.365605335e+01   1.2e-04  0.14
# 7   1.7e-06  2.7e-06  4.5e-03  1.00e+00   2.365232505e+01   2.365232435e+01   1.4e-06  0.16
# 8   4.0e-10  6.4e-10  6.9e-05  1.00e+00   2.365228070e+01   2.365228070e+01   3.2e-10  0.17
# Optimizer terminated. Time: 0.17
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.3652280702e+01    nrm: 7e+01    Viol.  con: 2e-10    var: 0e+00    barvar: 0e+00
#   Dual.    obj: 2.3652280702e+01    nrm: 2e+00    Viol.  con: 1e-10    var: 1e-10    barvar: 1e-10
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 4832
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.03
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7367
#   Cones                  : 0
#   Scalar variables       : 2261
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1191
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2173              conic                  : 157
# Optimizer  - Semi-definite variables: 1                 scalarized             : 300
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.51e+04          after factor           : 5.53e+04
# Factor     - dense dim.             : 0                 flops                  : 9.64e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.3e+00  2.0e+00  1.0e+00  0.00e+00   8.798656248e-13   8.798656248e-13   1.0e+00  0.05
# 1   7.5e-01  1.2e+00  1.2e+00  2.93e+00   4.369740038e+01   4.351944704e+01   6.0e-01  0.06
# 2   6.4e-01  1.0e+00  1.1e+00  2.04e+00   3.624661227e+01   3.614864544e+01   5.1e-01  0.08
# Excessive output truncated after 524353 bytes.
# 3   2.0e-01  3.2e-01  9.7e-01  2.21e+00   2.901258092e+01   2.896431011e+01   1.6e-01  0.09
# 4   7.1e-02  1.1e-01  6.6e-01  1.35e+00   2.579395053e+01   2.577388699e+01   5.7e-02  0.11
# 5   4.4e-03  7.1e-03  2.4e-01  1.15e+00   2.412887816e+01   2.412691930e+01   3.6e-03  0.14
# 6   7.2e-04  1.2e-03  9.8e-02  1.04e+00   2.403456553e+01   2.403424827e+01   5.8e-04  0.16
# 7   6.5e-05  1.0e-04  3.4e-02  1.01e+00   2.401782885e+01   2.401779755e+01   5.2e-05  0.17
# 348.042923154

# %%
P
# Out:
# 27×4 Array{Any,2}:
#  23.1429    29.4286    20.2478     24.037
#  10.97      15.8798     9.57524    13.4745
#  13.1429    12.2857     2.56032    13.9378
#   2.88479    6.0067     1.68158    11.0823
#   8.85714    4.85285    0.326723    8.95383
#   2.91919    2.97313    2.09707     8.05669
#   4.0        0.99213    0.485835    6.61726
#   0.571429   0.963122   0.590601    7.94593
#   1.71429    0.0        0.0258158   8.35717
#   1.17272    0.688498   0.40354     5.12882
#   2.28571    0.25742    0.214378    3.45547
#   0.285714   0.285714   0.0754918   4.67131
#   0.571428   0.0        0.0         6.19382
#   ⋮
#   0.571429   0.0        0.0         5.20045
#   0.285714   0.0        0.0         4.94616
#   0.285714   0.0        0.0         4.23476
#   0.0        0.32632    0.0         2.99431
#   0.285714   0.0        0.0         4.48505
#   0.285714   0.0        0.0340052   2.36109
#   0.0        0.0        0.0         4.20102
#   0.0        0.0        0.0         2.28079
#   0.0        0.0        0.0         4.62442
#   0.0        0.0        0.0         1.7886
#   0.0        0.0        0.0         2.65563
#   0.0        0.0        0.0         4.72861

# %%
#19.9 min
plot(1:1:27,P[1:27,1],label="delta=0.01","-bo")
plot(1:1:27,P[1:27,2],label="delta=0.5","-gs")
plot(1:1:27,P[1:27,3],label="delta=0.8","-m+")
plot(1:1:27,P[1:27,4],label="delta=1.5","-r^")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000023985CF8>)
# PyObject <matplotlib.legend.Legend object at 0x0000000023A36080>

# %% [markdown]
# <h2>Aprendizaje con norma  espectral sin 1 en la diagonal <h2>

# %%
tic()
P = evaluarGraphLearningEspectral6(0.7,0.3,0.01)
for s in [0.2,0.5,0.8,1.1,1.5,2]
    A = evaluarGraphLearningEspectral6(0.7,0.3,s)
    P = [P A]
    println(s)
end
toc()

# %%
#14.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.2")
plot(1:1:30,P[1:30,3],label="delta=0.5")
plot(1:1:30,P[1:30,4],label="delta=0.8")
plot(1:1:30,P[1:30,5],label="delta=1.1")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")


grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h2>Aprendizaje con grafo promedio <h2>

# %%
#u = 200
P = evaluarGraphLearningMean6(0.7,0.3,false)
#plot(1:1:30,P,label="NumExperimentos=200")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
P

# %% [markdown]
# <h4>En 30 observaciones el error no decrese. Aumentaremos las observaciones.<h4>

# %%
#u = 200
P = evaluarGraphLearningMean6(0.7,0.3,false)
plot(1:1:100,P,label="NumExperimentos=200")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
asdf=Array{Any}(1000)
[asdf[r]=erdosgraph([0.7,1],0.1,[5,5],10) for r in 1:1000]
papa=meanGraphLearn(asdf,false)

# %% [markdown]
# <h4>El metodo esta recuperando las probabilidades intra y outra cluster. Toca redeondear para ser comparable.<h4>

# %%
#u = 200
P = evaluarGraphLearningMean6(0.7,0.3,true)
plot(1:1:50,P,label="NumExperimentos=200")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3> l2 redondeado<h3>

# %%
tic()
P = evaluarGraphLearningl262(0.7,0.3,0.01,true)
for s in [0.05,0.1,0.15,0.2,1.5,2]
    A = evaluarGraphLearningl262(0.7,0.3,s,true)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:40,P[1:40,1],label="delta=0.01")
plot(1:1:40,P[1:40,2],label="delta=0.05")
plot(1:1:40,P[1:40,3],label="delta=0.1")
plot(1:1:40,P[1:40,4],label="delta=0.15")
plot(1:1:40,P[1:40,5],label="delta=0.2")
plot(1:1:40,P[1:40,6],label="delta=1.5")
plot(1:1:40,P[1:40,7],label="delta=2")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3>espectral redondeado<h3>

# %%
tic()
P = evaluarGraphLearningEspectral6(0.7,0.3,0.01,true)
for s in [0.2,0.5,0.8,1.1,1.5,2]
    A = evaluarGraphLearningEspectral6(0.7,0.3,s,true)
    P = [P A]
    println(s)
end
toc()

# %%
#19.9 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.2")
plot(1:1:30,P[1:30,3],label="delta=0.5")
plot(1:1:30,P[1:30,4],label="delta=0.8")
plot(1:1:30,P[1:30,5],label="delta=1.1")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")


grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h1>Quedé algo preocupado con el metodo l2. Vamos a hacer mas simulaciones para grafos mas grandes<h1>

# %%
tic()
P = evaluarGraphLearningl26grande(0.6,0.2,0.01,false)
for s in [0.05,0.1,0.15,0.2,1.5,2]
    A = evaluarGraphLearningl26grande(0.6,0.2,s,false)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.05")
plot(1:1:30,P[1:30,3],label="delta=0.1")
plot(1:1:30,P[1:30,4],label="delta=0.15")
plot(1:1:30,P[1:30,5],label="delta=0.2")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3>Ahora redondeamos...<h3>

# %%
tic()
P = evaluarGraphLearningl26grande(0.6,0.2,0.01,true)
for s in [0.05,0.1,0.15,0.2]
    A = evaluarGraphLearningl26grande(0.6,0.2,s,true)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.05")
plot(1:1:30,P[1:30,3],label="delta=0.1")
plot(1:1:30,P[1:30,4],label="delta=0.15")
plot(1:1:30,P[1:30,5],label="delta=0.2")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3> y comparamos con el promedio...<h3>

# %%
#u = 200
Q = evaluarGraphLearningMean6Grande(0.6,0.2,true)
plot(1:1:30,Q,label="NumExperimentos=100")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3> Por ultimo comparamos con el metodo lineal<h3>

# %%
tic()
P = evaluarGraphLearninglineal6grande(0.6,0.2,0.01,false)
for s in [0.05,0.1,0.15,0.2,1.5,2]
    A = evaluarGraphLearninglineal6grande(0.6,0.2,s,false)
    P = [P A]
    println(s)
end
toc()

# %%
#8.3 min
plot(1:1:30,P[1:30,1],label="delta=0.01")
plot(1:1:30,P[1:30,2],label="delta=0.05")
plot(1:1:30,P[1:30,3],label="delta=0.1")
plot(1:1:30,P[1:30,4],label="delta=0.15")
plot(1:1:30,P[1:30,5],label="delta=0.2")
plot(1:1:30,P[1:30,6],label="delta=1.5")
plot(1:1:30,P[1:30,7],label="delta=2")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h2>Comparacion de las diferentes recuperaciones manteniendo las observaciones fijas.<h2>

# %% [markdown]
# <h3>Fijamos grafos con 3 clusters, de tamanos 8,17 y 25. Proba de conectar intracluster:0.75. Proba de contectar afuera de cluster:
# 0.2<h3>

# %% [markdown]
# <h3>N=3<h3>

# %%
resultadoL1=evaluarLinearGraphLearning4(0.75,0.2,3,0:0.5:10)

# %%
resultadoL2=evaluarl2GraphLearning4(0.75,0.2,3,0:0.5:10)

# %%
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,3,0:0.5:10)

# %%
1+1

# %%
#Este valor es constante ya no que delta no juega ningun papel en la recuperacion por promedio.
ErrorRecuperaRedondeado=meanGraphErrorObtained(0.75,0.2,3)
resultadoPromedioRedondeado = fill(ErrorRecuperaRedondeado,length(resultadoL1[2]))

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="Recovery using norm 1, 3 observations","-b^")
title("Error of recovery for different norms and varying \$\\delta\$")

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="Recovery using norm 1, 3 observations.","-bo")
p = zeros(length(interval))
plot(interval,resultadoL2[1],label="Recovery with norm 2, 3 observations.","-gs")
plot(interval,resultadoEspectral[1],label="Recovery using spectral norm, 3 observations.","-m+")
plot(interval,resultadoPromedioRedondeado,label="Recovery using the rounded mean, 3 observations.","-r^")
plot(interval,p,label="y=0.")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
title("Error of recovery for different norms with 3 observations and varying \$\\delta\$")

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="recuperacion con norma 1, 3 observaciones")
p = zeros(length(interval))
plot(interval,p,label="y=0")
plot(interval,resultadoL2[1],label="recuperacion con norma 2, 3 observaciones")
plot(interval,resultadoEspectral[1],label="recuperacion espectral(ADMM), 3 observaciones")
plot(interval,resultadoPromedioRedondeado,label="recuperacion promedio redondeado, 3 observaciones")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3>N=5<h3>

# %%
resultadoL1=evaluarLinearGraphLearning4(0.75,0.2,5,0:0.5:10)
resultadoL2=evaluarl2GraphLearning4(0.75,0.2,5,0:0.5:10)
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,5,0:0.5:10)
ErrorRecuperaRedondeado=meanGraphErrorObtained(0.75,0.2,5)
resultadoPromedioRedondeado = fill(ErrorRecuperaRedondeado,length(resultadoL1[2]))

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="recuperacion con norma 1, 5 observaciones")
p = zeros(length(interval))
plot(interval,p,label="y=0")
plot(interval,resultadoL2[1],label="recuperacion con norma 2, 5 observaciones")
plot(interval,resultadoEspectral[1],label="recuperacion espectral(ADMM), 5 observaciones")
plot(interval,resultadoPromedioRedondeado,label="recuperacion promedio redondeado, 5 observaciones")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3>N=7<h3>

# %%
resultadoL1=evaluarLinearGraphLearning4(0.75,0.2,7,0:0.5:10)
resultadoL2=evaluarl2GraphLearning4(0.75,0.2,7,0:0.5:10)
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,7,0:0.5:10)
ErrorRecuperaRedondeado=meanGraphErrorObtained(0.75,0.2,7)
resultadoPromedioRedondeado = fill(ErrorRecuperaRedondeado,length(resultadoL1[2]))

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="Recovery using norm 1, 10 observations.","-bo")
p = zeros(length(interval))
plot(interval,resultadoL2[1],label="Recovery with norm 2, 7 observations.","-gs")
plot(interval,resultadoEspectral[1],label="Recovery using spectral norm, 7 observations.","-m+")
plot(interval,resultadoPromedioRedondeado,label="Recovery using the rounded mean, 7 observations.","-r^")
plot(interval,p,label="y=0")
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
title("Error of recovery for different norms with 7 observations and varying \$\\delta\$")

# %% [markdown]
# <h3>N=20<h3>

# %%
resultadoL1=evaluarLinearGraphLearning4(0.75,0.2,20,0:0.5:10)
resultadoL2=evaluarl2GraphLearning4(0.75,0.2,20,0:0.5:10)
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,20,0:0.5:10)
ErrorRecuperaRedondeado=meanGraphErrorObtained(0.75,0.2,20)
resultadoPromedioRedondeado = fill(ErrorRecuperaRedondeado,length(resultadoL1[2]))

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="recuperacion con norma 1,20 observaciones")
p = zeros(length(interval))
plot(interval,p,label="y=0")
plot(interval,resultadoL2[1],label="recuperacion con norma 2, 20 observaciones")
plot(interval,resultadoEspectral[1],label="recuperacion espectral(ADMM), 20 observaciones")
plot(interval,resultadoPromedioRedondeado,label="recuperacion promedio redondeado, 20 observaciones")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %% [markdown]
# <h3>N=1<h3>

# %%
resultadoL1=evaluarLinearGraphLearning4(0.75,0.2,1,0:0.5:10)
resultadoL2=evaluarl2GraphLearning4(0.75,0.2,1,0:0.5:10)
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,1,0:0.5:10)
ErrorRecuperaRedondeado=meanGraphErrorObtained(0.75,0.2,1)
resultadoPromedioRedondeado = fill(ErrorRecuperaRedondeado,length(resultadoL1[2]))

# %%
interval= resultadoL1[2]
plot(interval,resultadoL1[1],label="recuperacion con norma 1, 1observaciones")
p = zeros(length(interval))
plot(interval,p,label="y=0")
plot(interval,resultadoL2[1],label="recuperacion con norma 2, 1 observaciones")
plot(interval,resultadoEspectral[1],label="recuperacion espectral(ADMM), 1 observaciones")
plot(interval,resultadoPromedioRedondeado,label="recuperacion promedio redondeado, 1 observaciones")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
#resultadoMosek = evaluarspectralGraphLearning4(0.75,0.2,3,0:0.5:8)
resultadoEspectral=evaluarADMMGraphLearning4(0.75,0.2,3,0:0.5:8)
interval= resultadoMosek[2]
plot(interval,resultadoMosek[1],label="recuperacion con mosek, 1observaciones")
p = zeros(length(interval))
plot(interval,p,label="y=0")
plot(interval,resultadoEspectral[1],label="recuperacion con admm, 1 observaciones")

grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
papa = 0:0.01:8

# %%
alpha = 0.25

# %%
n = 50

# %%
func=function(delta)
    return(delta*(alpha-delta/n)^2/(1+2*delta/n))
end

# %%
resultado= map(func,papa
)

# %%
plot(papa,resultado)
grid("on")
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)

# %%
learnGraph(weights,delta,B,n)

# %%
B=Array{Any}(3)
B[1]=erdosgraph([0.75,0.75],0.2,[15,15],30)
B[2]=erdosgraph([0.75,0.75],0.2,[15,15],30)
B[3]=erdosgraph([0.75,0.75],0.2,[15,15],30)

respuesta=learnEspectralGraph(ones(3)/3,0.8,B,30)

# %%
respuesta[1]

# %%
admm = admmRecovery(B,0.8,30,3.2,1.0e-4,400)

# %%
papa = (admm[1]+ones(30)*ones(30)')/2

# %%
norm(papa-respuesta[1],2)

# %% [markdown]
# <h3>Recuperacion usando ADMM, cambiando los parametros pintro y outra<h3>

# %%
admm3p1 = evaluarADMMGraphLearning3(1.5,1)

# %%
admm3

# %%
spectral3 =evaluarspectralGraphLearning3(1.5,1)

# %%
imshow(admm3)
title("Probability of recovery with 1 observation for different values of \$ p\$ and \$q\$.")
xlabel("Probability of an edge between clusters")
ylabel("Probability of an edge inside a cluster")

# %%
admm3p2 = evaluarADMMGraphLearning3(1.5,3)

# %%
imshow(admm3p2)

title("Probability of recovery with 3 observations for different values of \$p\$ and \$q\$.")
xlabel("Probability of an edge between clusters.")
ylabel("Probability of an edge inside a cluster.")

# %%
admm3p3 = evaluarADMMGraphLearning3(0.8,7)

# %%
imshow(admm3p3)

title("Probability of recovery with 7 observations for different values of \$p\$ and \$q\$.")
xlabel("Probability of an edge between clusters")
ylabel("Probability of an edge inside a cluster")

# %%
imshow(admm3p4)

title("Probability of recovery with 25 observations for different values of \$p\$ and \$q\$.")
xlabel("Probability of an edge between clusters")
ylabel("Probability of an edge inside a cluster")

# %%
admm3p4 = evaluarADMMGraphLearning3(0.8,25)

# %%
B=Array{Any}(2)
grafo1 = erdosgraph([0.75,0.75],0.2,[15,35],50)
grafo2 = erdosgraph([0.75,0.75],0.2,[15,35],50)
B[1]=grafo1+diagm(ones(50))
B[2]=grafo2+diagm(ones(50))

# %%
cd("C:\\Users\\Daniel\\MasterThesis\\GraphProyects")

# %%
grafo1

# %%
writecsv("grafo1.txt", grafo1)
writecsv("grafo2.txt", grafo2)

# %%
bli =admmRecovery(B,14,50,1.6,1.0e-3,400)
recupera =(bli[1]+ones(50)*ones(50)')/2
recupera2 = round.(recupera,3)
writecsv("recupera.txt", recupera2)

# %%
recupera

# %%
writecsv("recupera.txt", recupera2)

# %%
bli =admmRecovery(B,1.5,50,1.6,1.0e-3,400)
recupera =(bli[1]+ones(50)*ones(50)')/2
